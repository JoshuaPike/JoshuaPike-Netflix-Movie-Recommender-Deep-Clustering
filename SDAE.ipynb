# %%
# Mount Google Drive
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import os
import os.path
import errno
import numpy as np
import gzip
import torch
import pickle
import torch.utils.data as data
import codecs
import urllib
class Netflix(data.Dataset):
    def __init__(self, root, train=True, transform=None, target_transform=None, download=False):
        self.root = os.path.expanduser(root)
        self.transform = transform
        self.target_transform = target_transform
        self.train = train  # training set or test set
        self.use_cuda = torch.cuda.is_available()
        self.training_file = "svd_pu2.npy" # your data for clustering (e.g., user-predictions matrix, user-embedding learned from SVD ...)
        self.label_file = "svd_pu_labels2.npy" # clustering labels (not applicable for our assignment, I used the k-means labels for svd_pu file)
        if download:
            self.download()
        train = np.load(self.training_file)
        from sklearn.preprocessing import StandardScaler
        scaler = StandardScaler()
        label = np.load(self.label_file)
        train = scaler.fit_transform(train)
        if self.train:
            self.train_data, self.train_labels = torch.tensor(train, dtype=torch.float32), torch.tensor(label, dtype=torch.int)
            if self.use_cuda:
                self.train_data = self.train_data.cuda()
                self.train_labels = self.train_labels.cuda()
        else:
            self.test_data, self.test_labels = torch.tensor(train, dtype=torch.float32), torch.tensor(label, dtype=torch.int)
            if self.use_cuda:
                self.test_data = self.test_data.cuda()
                self.test_labels = self.test_labels.cuda()
    def __getitem__(self, index):
        if self.train:
            img, target = self.train_data[index], self.train_labels[index]
        else:
            img, target = self.test_data[index], self.test_labels[index]

        return img, target

    def __len__(self):
        if self.train:
            return len(self.train_data)
        else:
            return len(self.test_data)

# %%
import torch
import torch.nn as nn
from torch.nn import Parameter
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
from torch.autograd import Variable
import numpy as np
import math

class Dataset(data.Dataset):
    def __init__(self, data, labels, transform=None, target_transform=None):
        self.transform = transform
        self.target_transform = target_transform
        self.data = data
        self.labels = labels
        if torch.cuda.is_available():
            self.data = self.data.cuda()
            self.labels = self.labels.cuda()

    def __getitem__(self, index):
        img, target = self.data[index], self.labels[index]
        # img = Image.fromarray(img)
        if self.transform is not None:
            img = self.transform(img)

        if self.target_transform is not None:
            target = self.target_transform(target)

        return img, target

    def __len__(self):
        return len(self.data)


def masking_noise(data, frac):
    """
    data: Tensor
    frac: fraction of unit to be masked out
    """
    data_noise = data.clone()
    rand = torch.rand(data.size())
    data_noise[rand<frac] = 0
    return data_noise

class MSELoss(nn.Module):
    def __init__(self):
        super(self.__class__, self).__init__()

    def forward(self, input, target):
        return 0.5 * torch.mean((input-target)**2)

class BCELoss(nn.Module):
    def __init__(self):
        super(self.__class__, self).__init__()

    def forward(self, input, target):
        return -torch.mean(torch.sum(target*torch.log(torch.clamp(input, min=1e-10))+
            (1-target)*torch.log(torch.clamp(1-input, min=1e-10)), 1))
        

def adjust_learning_rate(init_lr, optimizer, epoch):
    lr = init_lr * (0.1 ** (epoch//100))
    toprint = True
    for param_group in optimizer.param_groups:
        if param_group["lr"]!=lr:
            param_group["lr"] = lr
            if toprint:
                print("Switching to learning rate %f" % lr)
                toprint = False

class DenoisingAutoencoder(nn.Module):
    def __init__(self, in_features, out_features, activation="relu", 
        dropout=0.2, tied=False):
        super(self.__class__, self).__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.weight = Parameter(torch.Tensor(out_features, in_features))
        if tied:
            self.deweight = self.weight.t()
        else:
            self.deweight = Parameter(torch.Tensor(in_features, out_features))
        self.bias = Parameter(torch.Tensor(out_features))
        self.vbias = Parameter(torch.Tensor(in_features))
        
        if activation=="relu":
            self.enc_act_func = nn.ReLU()
        elif activation=="sigmoid":
            self.enc_act_func = nn.Sigmoid()
        elif activation=="none":
            self.enc_act_func = None
        self.dropout = nn.Dropout(p=dropout)

        self.reset_parameters()

    def reset_parameters(self):
        stdv = 0.01
        self.weight.data.uniform_(-stdv, stdv)
        self.bias.data.uniform_(-stdv, stdv)
        stdv = 0.01
        self.deweight.data.uniform_(-stdv, stdv)
        self.vbias.data.uniform_(-stdv, stdv)

    def forward(self, x):
        if self.enc_act_func is not None:
            return self.dropout(self.enc_act_func(F.linear(x, self.weight, self.bias)))
        else:
            return self.dropout(F.linear(x, self.weight, self.bias))

    def encode(self, x, train=True):
        if train:
            self.dropout.train()
        else:
            self.dropout.eval()
        if self.enc_act_func is not None:
            return self.dropout(self.enc_act_func(F.linear(x, self.weight, self.bias)))
        else:
            return self.dropout(F.linear(x, self.weight, self.bias))

    def encodeBatch(self, dataloader):
        use_cuda = torch.cuda.is_available()
        encoded = []
        for batch_idx, (inputs, _) in enumerate(dataloader):
            inputs = inputs.view(inputs.size(0), -1).float()
            if use_cuda:
                inputs = inputs.cuda()
            inputs = Variable(inputs)
            hidden = self.encode(inputs, train=False)
            encoded.append(hidden.data.cpu())

        encoded = torch.cat(encoded, dim=0)
        return encoded

    def decode(self, x, binary=False):
        if not binary:
            return F.linear(x, self.deweight, self.vbias)
        else:
            return F.sigmoid(F.linear(x, self.deweight, self.vbias))

    def fit(self, trainloader, validloader, lr=0.001, batch_size=128, num_epochs=10, corrupt=0.3,
        loss_type="mse"):
        """
        data_x: FloatTensor
        valid_x: FloatTensor
        """
        use_cuda = torch.cuda.is_available()
        if use_cuda:
            self.cuda()
        print("=====Denoising Autoencoding layer=======")
        # optimizer = optim.Adam(filter(lambda p: p.requires_grad, self.parameters()), lr=lr)
        optimizer = optim.SGD(filter(lambda p: p.requires_grad, self.parameters()), lr=lr, momentum=0.9)
        if loss_type=="mse":
            criterion = MSELoss()
        elif loss_type=="cross-entropy":
            criterion = BCELoss()

        # validate
        total_loss = 0.0
        total_num = 0
        for batch_idx, (inputs, _) in enumerate(validloader):
            # inputs = inputs.view(inputs.size(0), -1).float()
            # if use_cuda:
            #     inputs = inputs.cuda()
            inputs = Variable(inputs)
            hidden = self.encode(inputs)
            if loss_type=="cross-entropy":
                outputs = self.decode(hidden, binary=True)
            else:
                outputs = self.decode(hidden)

            valid_recon_loss = criterion(outputs, inputs)
            total_loss += valid_recon_loss.data * len(inputs)
            total_num += inputs.size()[0]

        valid_loss = total_loss / total_num
        print("#Epoch 0: Valid Reconstruct Loss: %.4f" % (valid_loss))

        self.train()
        for epoch in range(num_epochs):
            # train 1 epoch
            train_loss = 0.0
            adjust_learning_rate(lr, optimizer, epoch)
            for batch_idx, (inputs, _) in enumerate(trainloader):
                # inputs = inputs.view(inputs.size(0), -1).float()
                inputs_corr = masking_noise(inputs, corrupt)
                # if use_cuda:
                #     inputs = inputs.cuda()
                #     inputs_corr = inputs_corr.cuda()
                optimizer.zero_grad()
                inputs = Variable(inputs)
                inputs_corr = Variable(inputs_corr)

                hidden = self.encode(inputs_corr)
                if loss_type=="cross-entropy":
                    outputs = self.decode(hidden, binary=True)
                else:
                    outputs = self.decode(hidden)
                recon_loss = criterion(outputs, inputs)
                train_loss += recon_loss.data*len(inputs)
                recon_loss.backward()
                optimizer.step()

            # validate
            valid_loss = 0.0
            for batch_idx, (inputs, _) in enumerate(validloader):
                # inputs = inputs.view(inputs.size(0), -1).float()
                # if use_cuda:
                #     inputs = inputs.cuda()
                inputs = Variable(inputs)
                hidden = self.encode(inputs, train=False)
                if loss_type=="cross-entropy":
                    outputs = self.decode(hidden, binary=True)
                else:
                    outputs = self.decode(hidden)

                valid_recon_loss = criterion(outputs, inputs)
                valid_loss += valid_recon_loss.data * len(inputs)

            print("#Epoch %3d: Reconstruct Loss: %.4f, Valid Reconstruct Loss: %.4f" % (
                epoch+1, train_loss / len(trainloader.dataset), valid_loss / len(validloader.dataset)))

    def extra_repr(self):
        return 'in_features={}, out_features={}, bias={}'.format(
            self.in_features, self.out_features, self.bias is not None
        )

# %%
import torch
import torch.nn as nn
from torch.nn import Parameter
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
from torch.autograd import Variable
import numpy as np
import math

def buildNetwork(layers, activation="relu", dropout=0):
    net = []
    for i in range(1, len(layers)):
        net.append(nn.Linear(layers[i-1], layers[i]))
        if activation=="relu":
            net.append(nn.ReLU())
        elif activation=="sigmoid":
            net.append(nn.Sigmoid())
        if dropout > 0:
            net.append(nn.Dropout(dropout))
    return nn.Sequential(*net)

def adjust_learning_rate(init_lr, optimizer, epoch):
    lr = init_lr * (0.1 ** (epoch//100))
    toprint = True
    for param_group in optimizer.param_groups:
        if param_group["lr"]!=lr:
            param_group["lr"] = lr
            if toprint:
                print("Switching to learning rate %f" % lr)
                toprint = False

class StackedDAE(nn.Module):
    def __init__(self, input_dim=784, z_dim=10, binary=True,
        encodeLayer=[400], decodeLayer=[400], activation="relu", 
        dropout=0, tied=False):
        super(self.__class__, self).__init__()
        self.z_dim = z_dim
        self.layers = [input_dim] + encodeLayer + [z_dim]
        self.activation = activation
        self.dropout = dropout
        self.encoder = buildNetwork([input_dim] + encodeLayer, activation=activation, dropout=dropout)
        self.decoder = buildNetwork([z_dim] + decodeLayer, activation=activation, dropout=dropout)
        self._enc_mu = nn.Linear(encodeLayer[-1], z_dim)
        
        self._dec = nn.Linear(decodeLayer[-1], input_dim)
        self._dec_act = None
        if binary:
            self._dec_act = nn.Sigmoid()

    def decode(self, z):
        h = self.decoder(z)
        x = self._dec(h)
        if self._dec_act is not None:
            x = self._dec_act(x)
        return x

    def loss_function(self, recon_x, x):
        loss = -torch.mean(torch.sum(x*torch.log(torch.clamp(recon_x, min=1e-10))+
            (1-x)*torch.log(torch.clamp(1-recon_x, min=1e-10)), 1))

        return loss

    def forward(self, x):
        h = self.encoder(x)
        z = self._enc_mu(h)

        return z, self.decode(z)

    def save_model(self, path):
        torch.save(self.state_dict(), path)

    def load_model(self, path):
        pretrained_dict = torch.load(path, map_location=lambda storage, loc: storage)
        model_dict = self.state_dict()
        pretrained_dict = {k: v for k, v in pretrained_dict.items() if k in model_dict}
        model_dict.update(pretrained_dict) 
        self.load_state_dict(model_dict)

    def pretrain(self, trainloader, validloader, lr=0.001, batch_size=128, num_epochs=10, corrupt=0.2, loss_type="cross-entropy"):
        trloader = trainloader
        valoader = validloader
        daeLayers = []
        for l in range(1, len(self.layers)):
            infeatures = self.layers[l-1]
            outfeatures = self.layers[l]
            if l!= len(self.layers)-1:
                dae = DenoisingAutoencoder(infeatures, outfeatures, activation=self.activation, dropout=corrupt)
            else:
                dae = DenoisingAutoencoder(infeatures, outfeatures, activation="none", dropout=0)
            print(dae)
            if l==1:
                dae.fit(trloader, valoader, lr=lr, batch_size=batch_size, num_epochs=num_epochs, corrupt=corrupt, loss_type=loss_type)
            else:
                if self.activation=="sigmoid":
                    dae.fit(trloader, valoader, lr=lr, batch_size=batch_size, num_epochs=num_epochs, corrupt=corrupt, loss_type="cross-entropy")
                else:
                    dae.fit(trloader, valoader, lr=lr, batch_size=batch_size, num_epochs=num_epochs, corrupt=corrupt, loss_type="mse")
            data_x = dae.encodeBatch(trloader)
            valid_x = dae.encodeBatch(valoader)
            trainset = Dataset(data_x, data_x)
            trloader = torch.utils.data.DataLoader(
                trainset, batch_size=batch_size, shuffle=True, num_workers=0)
            validset = Dataset(valid_x, valid_x)
            valoader = torch.utils.data.DataLoader(
                validset, batch_size=1000, shuffle=False, num_workers=0)
            daeLayers.append(dae)

        self.copyParam(daeLayers)

    def copyParam(self, daeLayers):
        if self.dropout==0:
            every = 2
        else:
            every = 3
        # input layer
        # copy encoder weight
        self.encoder[0].weight.data.copy_(daeLayers[0].weight.data)
        self.encoder[0].bias.data.copy_(daeLayers[0].bias.data)
        self._dec.weight.data.copy_(daeLayers[0].deweight.data)
        self._dec.bias.data.copy_(daeLayers[0].vbias.data)

        for l in range(1, len(self.layers)-2):
            # copy encoder weight
            self.encoder[l*every].weight.data.copy_(daeLayers[l].weight.data)
            self.encoder[l*every].bias.data.copy_(daeLayers[l].bias.data)

            # copy decoder weight
            self.decoder[-(l-1)*every-2].weight.data.copy_(daeLayers[l].deweight.data)
            self.decoder[-(l-1)*every-2].bias.data.copy_(daeLayers[l].vbias.data)

        # z layer
        self._enc_mu.weight.data.copy_(daeLayers[-1].weight.data)
        self._enc_mu.bias.data.copy_(daeLayers[-1].bias.data)
        self.decoder[0].weight.data.copy_(daeLayers[-1].deweight.data)
        self.decoder[0].bias.data.copy_(daeLayers[-1].vbias.data)

    def fit(self, trainloader, validloader, lr=0.001, num_epochs=10, corrupt=0.3,
        loss_type="mse"):
        """
        data_x: FloatTensor
        valid_x: FloatTensor
        """
        use_cuda = torch.cuda.is_available()
        if use_cuda:
            self.cuda()
        print("=====Stacked Denoising Autoencoding Layer=======")
        # optimizer = optim.Adam(filter(lambda p: p.requires_grad, self.parameters()), lr=lr)
        optimizer = optim.SGD(filter(lambda p: p.requires_grad, self.parameters()), lr=lr, momentum=0.9)
        if loss_type=="mse":
            criterion = MSELoss()
        elif loss_type=="cross-entropy":
            criterion = BCELoss()

        # validate
        total_loss = 0.0
        total_num = 0
        for batch_idx, (inputs, _) in enumerate(validloader):
            inputs = inputs.view(inputs.size(0), -1).float()
            if use_cuda:
                inputs = inputs.cuda()
            inputs = Variable(inputs)
            z, outputs = self.forward(inputs)

            valid_recon_loss = criterion(outputs, inputs)
            total_loss += valid_recon_loss.data * len(inputs)
            total_num += inputs.size()[0]

        valid_loss = total_loss / total_num
        print("#Epoch 0: Valid Reconstruct Loss: %.4f" % (valid_loss))
        self.train()
        for epoch in range(num_epochs):
            # train 1 epoch
            adjust_learning_rate(lr, optimizer, epoch)
            train_loss = 0.0
            for batch_idx, (inputs, _) in enumerate(trainloader):
                inputs = inputs.view(inputs.size(0), -1).float()
                inputs_corr = masking_noise(inputs, corrupt)
                if use_cuda:
                    inputs = inputs.cuda()
                    inputs_corr = inputs_corr.cuda()
                optimizer.zero_grad()
                inputs = Variable(inputs)
                inputs_corr = Variable(inputs_corr)

                z, outputs = self.forward(inputs_corr)
                recon_loss = criterion(outputs, inputs)
                train_loss += recon_loss.data*len(inputs)
                recon_loss.backward()
                optimizer.step()

            # validate
            valid_loss = 0.0
            for batch_idx, (inputs, _) in enumerate(validloader):
                inputs = inputs.view(inputs.size(0), -1).float()
                if use_cuda:
                    inputs = inputs.cuda()
                inputs = Variable(inputs)
                z, outputs = self.forward(inputs)

                valid_recon_loss = criterion(outputs, inputs)
                valid_loss += valid_recon_loss.data * len(inputs)

            print("#Epoch %3d: Reconstruct Loss: %.4f, Valid Reconstruct Loss: %.4f" % (
                epoch+1, train_loss / len(trainloader.dataset), valid_loss / len(validloader.dataset)))

# %%
import sys
sys.path.append("..")
import torch.utils.data
import argparse


if __name__ == "__main__":
    # Load data for pre-training
    train_loader = torch.utils.data.DataLoader(
        Netflix('', train=True),
        batch_size=256, shuffle=True, num_workers=0)
    test_loader = torch.utils.data.DataLoader(
        Netflix('', train=False),
        batch_size=256, shuffle=False, num_workers=0)

    sdae = StackedDAE(input_dim=10, z_dim=20, binary=False,
                      encodeLayer=[500, 500, 2000], decodeLayer=[2000, 500, 500], activation="relu",
                      dropout=0)
    
    # Print the pre-train model structure
    print(sdae)
    sdae.pretrain(train_loader, test_loader, lr=0.1, batch_size=256,
                  num_epochs=300, corrupt=0.2, loss_type="mse")
    
    # Train the stacked denoising autoencoder
    sdae.fit(train_loader, test_loader, lr=0.1, num_epochs=500, corrupt=0.2, loss_type="mse")
    
    # Save the weights as pre-trained model for IDEC/DEC/DCC
    sdae.save_model("sdae_netflix_weights.pt")
# Out:
# StackedDAE(
#   (encoder): Sequential(
#     (0): Linear(in_features=10, out_features=500, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=500, out_features=500, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=500, out_features=2000, bias=True)
#     (5): ReLU()
#   )
#   (decoder): Sequential(
#     (0): Linear(in_features=20, out_features=2000, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=2000, out_features=500, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=500, out_features=500, bias=True)
#     (5): ReLU()
#   )
#   (_enc_mu): Linear(in_features=2000, out_features=20, bias=True)
#   (_dec): Linear(in_features=500, out_features=10, bias=True)
# )
# DenoisingAutoencoder(
#   in_features=10, out_features=500, bias=True
#   (enc_act_func): ReLU()
#   (dropout): Dropout(p=0.2, inplace=False)
# )
# =====Denoising Autoencoding layer=======
# #Epoch 0: Valid Reconstruct Loss: 0.5000
# #Epoch   1: Reconstruct Loss: 0.3311, Valid Reconstruct Loss: 0.0369
# #Epoch   2: Reconstruct Loss: 0.0446, Valid Reconstruct Loss: 0.0701
# #Epoch   3: Reconstruct Loss: 0.0311, Valid Reconstruct Loss: 0.0438
# #Epoch   4: Reconstruct Loss: 0.0349, Valid Reconstruct Loss: 0.0567
# #Epoch   5: Reconstruct Loss: 0.0614, Valid Reconstruct Loss: 0.0645
# #Epoch   6: Reconstruct Loss: 0.0329, Valid Reconstruct Loss: 0.0204
# #Epoch   7: Reconstruct Loss: 0.0455, Valid Reconstruct Loss: 0.0189
# #Epoch   8: Reconstruct Loss: 0.0211, Valid Reconstruct Loss: 0.0256
# #Epoch   9: Reconstruct Loss: 0.0309, Valid Reconstruct Loss: 0.0241
# #Epoch  10: Reconstruct Loss: 0.0217, Valid Reconstruct Loss: 0.0212
# #Epoch  11: Reconstruct Loss: 0.0370, Valid Reconstruct Loss: 0.0411
# #Epoch  12: Reconstruct Loss: 0.0372, Valid Reconstruct Loss: 0.0567
# #Epoch  13: Reconstruct Loss: 0.0343, Valid Reconstruct Loss: 0.0110
# #Epoch  14: Reconstruct Loss: 0.0249, Valid Reconstruct Loss: 0.0174
# #Epoch  15: Reconstruct Loss: 0.0215, Valid Reconstruct Loss: 0.0177
# #Epoch  16: Reconstruct Loss: 0.0259, Valid Reconstruct Loss: 0.0909
# #Epoch  17: Reconstruct Loss: 0.0207, Valid Reconstruct Loss: 0.0258
# #Epoch  18: Reconstruct Loss: 0.0258, Valid Reconstruct Loss: 0.0064
# #Epoch  19: Reconstruct Loss: 0.0318, Valid Reconstruct Loss: 0.0065
# #Epoch  20: Reconstruct Loss: 0.0216, Valid Reconstruct Loss: 0.0586
# #Epoch  21: Reconstruct Loss: 0.0188, Valid Reconstruct Loss: 0.0106
# #Epoch  22: Reconstruct Loss: 0.0228, Valid Reconstruct Loss: 0.0617
# #Epoch  23: Reconstruct Loss: 0.0232, Valid Reconstruct Loss: 0.0260
# #Epoch  24: Reconstruct Loss: 0.0198, Valid Reconstruct Loss: 0.0386
# #Epoch  25: Reconstruct Loss: 0.0294, Valid Reconstruct Loss: 0.0203
# #Epoch  26: Reconstruct Loss: 0.0164, Valid Reconstruct Loss: 0.0244
# #Epoch  27: Reconstruct Loss: 0.0195, Valid Reconstruct Loss: 0.0084
# #Epoch  28: Reconstruct Loss: 0.0215, Valid Reconstruct Loss: 0.0616
# #Epoch  29: Reconstruct Loss: 0.0180, Valid Reconstruct Loss: 0.0072
# #Epoch  30: Reconstruct Loss: 0.0182, Valid Reconstruct Loss: 0.0058
# #Epoch  31: Reconstruct Loss: 0.0184, Valid Reconstruct Loss: 0.0343
# #Epoch  32: Reconstruct Loss: 0.0181, Valid Reconstruct Loss: 0.0106
# #Epoch  33: Reconstruct Loss: 0.0235, Valid Reconstruct Loss: 0.0139
# #Epoch  34: Reconstruct Loss: 0.0162, Valid Reconstruct Loss: 0.0159
# #Epoch  35: Reconstruct Loss: 0.0179, Valid Reconstruct Loss: 0.0190
# #Epoch  36: Reconstruct Loss: 0.0148, Valid Reconstruct Loss: 0.0332
# #Epoch  37: Reconstruct Loss: 0.0153, Valid Reconstruct Loss: 0.0199
# #Epoch  38: Reconstruct Loss: 0.0169, Valid Reconstruct Loss: 0.0167
# #Epoch  39: Reconstruct Loss: 0.0170, Valid Reconstruct Loss: 0.0093
# #Epoch  40: Reconstruct Loss: 0.0268, Valid Reconstruct Loss: 0.0085
# #Epoch  41: Reconstruct Loss: 0.0196, Valid Reconstruct Loss: 0.0125
# #Epoch  42: Reconstruct Loss: 0.0190, Valid Reconstruct Loss: 0.0107
# #Epoch  43: Reconstruct Loss: 0.0155, Valid Reconstruct Loss: 0.0186
# #Epoch  44: Reconstruct Loss: 0.0178, Valid Reconstruct Loss: 0.0212
# #Epoch  45: Reconstruct Loss: 0.0171, Valid Reconstruct Loss: 0.0188
# #Epoch  46: Reconstruct Loss: 0.0139, Valid Reconstruct Loss: 0.0099
# #Epoch  47: Reconstruct Loss: 0.0140, Valid Reconstruct Loss: 0.0156
# #Epoch  48: Reconstruct Loss: 0.0125, Valid Reconstruct Loss: 0.0104
# #Epoch  49: Reconstruct Loss: 0.0139, Valid Reconstruct Loss: 0.0387
# #Epoch  50: Reconstruct Loss: 0.0162, Valid Reconstruct Loss: 0.0051
# #Epoch  51: Reconstruct Loss: 0.0222, Valid Reconstruct Loss: 0.0323
# #Epoch  52: Reconstruct Loss: 0.0141, Valid Reconstruct Loss: 0.0329
# #Epoch  53: Reconstruct Loss: 0.0110, Valid Reconstruct Loss: 0.0102
# #Epoch  54: Reconstruct Loss: 0.0129, Valid Reconstruct Loss: 0.0160
# #Epoch  55: Reconstruct Loss: 0.0123, Valid Reconstruct Loss: 0.0167
# #Epoch  56: Reconstruct Loss: 0.0105, Valid Reconstruct Loss: 0.0163
# #Epoch  57: Reconstruct Loss: 0.0136, Valid Reconstruct Loss: 0.3710
# #Epoch  58: Reconstruct Loss: 0.3786, Valid Reconstruct Loss: 0.1717
# #Epoch  59: Reconstruct Loss: 0.1191, Valid Reconstruct Loss: 0.0423
# #Epoch  60: Reconstruct Loss: 0.0435, Valid Reconstruct Loss: 0.0720
# #Epoch  61: Reconstruct Loss: 0.0323, Valid Reconstruct Loss: 0.0210
# #Epoch  62: Reconstruct Loss: 0.0245, Valid Reconstruct Loss: 0.0104
# #Epoch  63: Reconstruct Loss: 0.0209, Valid Reconstruct Loss: 0.0086
# #Epoch  64: Reconstruct Loss: 0.0213, Valid Reconstruct Loss: 0.0193
# #Epoch  65: Reconstruct Loss: 0.0254, Valid Reconstruct Loss: 0.0084
# #Epoch  66: Reconstruct Loss: 0.0188, Valid Reconstruct Loss: 0.0111
# #Epoch  67: Reconstruct Loss: 0.0143, Valid Reconstruct Loss: 0.0135
# #Epoch  68: Reconstruct Loss: 0.0189, Valid Reconstruct Loss: 0.0174
# #Epoch  69: Reconstruct Loss: 0.0197, Valid Reconstruct Loss: 0.0054
# #Epoch  70: Reconstruct Loss: 0.0203, Valid Reconstruct Loss: 0.0130
# #Epoch  71: Reconstruct Loss: 0.0181, Valid Reconstruct Loss: 0.0124
# #Epoch  72: Reconstruct Loss: 0.0198, Valid Reconstruct Loss: 0.0245
# #Epoch  73: Reconstruct Loss: 0.0201, Valid Reconstruct Loss: 0.0118
# #Epoch  74: Reconstruct Loss: 0.0133, Valid Reconstruct Loss: 0.0075
# #Epoch  75: Reconstruct Loss: 0.0151, Valid Reconstruct Loss: 0.0122
# #Epoch  76: Reconstruct Loss: 0.0135, Valid Reconstruct Loss: 0.0241
# #Epoch  77: Reconstruct Loss: 0.0155, Valid Reconstruct Loss: 0.0056
# #Epoch  78: Reconstruct Loss: 0.0153, Valid Reconstruct Loss: 0.0086
# #Epoch  79: Reconstruct Loss: 0.0241, Valid Reconstruct Loss: 0.0074
# #Epoch  80: Reconstruct Loss: 0.0195, Valid Reconstruct Loss: 0.0179
# #Epoch  81: Reconstruct Loss: 0.0134, Valid Reconstruct Loss: 0.0065
# #Epoch  82: Reconstruct Loss: 0.0127, Valid Reconstruct Loss: 0.0073
# #Epoch  83: Reconstruct Loss: 0.0144, Valid Reconstruct Loss: 0.0075
# #Epoch  84: Reconstruct Loss: 0.0156, Valid Reconstruct Loss: 0.0162
# #Epoch  85: Reconstruct Loss: 0.0154, Valid Reconstruct Loss: 0.0058
# #Epoch  86: Reconstruct Loss: 0.0152, Valid Reconstruct Loss: 0.0132
# #Epoch  87: Reconstruct Loss: 0.0131, Valid Reconstruct Loss: 0.0120
# #Epoch  88: Reconstruct Loss: 0.0155, Valid Reconstruct Loss: 0.0141
# #Epoch  89: Reconstruct Loss: 0.0124, Valid Reconstruct Loss: 0.0105
# #Epoch  90: Reconstruct Loss: 0.0252, Valid Reconstruct Loss: 0.0242
# #Epoch  91: Reconstruct Loss: 0.0256, Valid Reconstruct Loss: 0.0112
# #Epoch  92: Reconstruct Loss: 0.0131, Valid Reconstruct Loss: 0.0083
# #Epoch  93: Reconstruct Loss: 0.0126, Valid Reconstruct Loss: 0.0071
# #Epoch  94: Reconstruct Loss: 0.0113, Valid Reconstruct Loss: 0.0050
# #Epoch  95: Reconstruct Loss: 0.0106, Valid Reconstruct Loss: 0.0052
# #Epoch  96: Reconstruct Loss: 0.0173, Valid Reconstruct Loss: 0.0586
# #Epoch  97: Reconstruct Loss: 0.0152, Valid Reconstruct Loss: 0.0093
# #Epoch  98: Reconstruct Loss: 0.0211, Valid Reconstruct Loss: 0.0059
# #Epoch  99: Reconstruct Loss: 0.0116, Valid Reconstruct Loss: 0.0098
# #Epoch 100: Reconstruct Loss: 0.0121, Valid Reconstruct Loss: 0.0206
# Switching to learning rate 0.010000
# #Epoch 101: Reconstruct Loss: 0.0131, Valid Reconstruct Loss: 0.0062
# #Epoch 102: Reconstruct Loss: 0.0096, Valid Reconstruct Loss: 0.0050
# #Epoch 103: Reconstruct Loss: 0.0143, Valid Reconstruct Loss: 0.0048
# #Epoch 104: Reconstruct Loss: 0.0102, Valid Reconstruct Loss: 0.0050
# #Epoch 105: Reconstruct Loss: 0.0115, Valid Reconstruct Loss: 0.0050
# #Epoch 106: Reconstruct Loss: 0.0109, Valid Reconstruct Loss: 0.0051
# #Epoch 107: Reconstruct Loss: 0.0096, Valid Reconstruct Loss: 0.0050
# #Epoch 108: Reconstruct Loss: 0.0090, Valid Reconstruct Loss: 0.0060
# #Epoch 109: Reconstruct Loss: 0.0091, Valid Reconstruct Loss: 0.0048
# #Epoch 110: Reconstruct Loss: 0.0092, Valid Reconstruct Loss: 0.0056
# #Epoch 111: Reconstruct Loss: 0.0094, Valid Reconstruct Loss: 0.0051
# #Epoch 112: Reconstruct Loss: 0.0087, Valid Reconstruct Loss: 0.0053
# #Epoch 113: Reconstruct Loss: 0.0105, Valid Reconstruct Loss: 0.0048
# #Epoch 114: Reconstruct Loss: 0.0091, Valid Reconstruct Loss: 0.0064
# #Epoch 115: Reconstruct Loss: 0.0094, Valid Reconstruct Loss: 0.0048
# #Epoch 116: Reconstruct Loss: 0.0096, Valid Reconstruct Loss: 0.0049
# #Epoch 117: Reconstruct Loss: 0.0085, Valid Reconstruct Loss: 0.0057
# #Epoch 118: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0047
# #Epoch 119: Reconstruct Loss: 0.0093, Valid Reconstruct Loss: 0.0047
# #Epoch 120: Reconstruct Loss: 0.0101, Valid Reconstruct Loss: 0.0056
# #Epoch 121: Reconstruct Loss: 0.0086, Valid Reconstruct Loss: 0.0046
# #Epoch 122: Reconstruct Loss: 0.0093, Valid Reconstruct Loss: 0.0044
# #Epoch 123: Reconstruct Loss: 0.0092, Valid Reconstruct Loss: 0.0056
# #Epoch 124: Reconstruct Loss: 0.0098, Valid Reconstruct Loss: 0.0051
# #Epoch 125: Reconstruct Loss: 0.0114, Valid Reconstruct Loss: 0.0056
# #Epoch 126: Reconstruct Loss: 0.0106, Valid Reconstruct Loss: 0.0048
# #Epoch 127: Reconstruct Loss: 0.0091, Valid Reconstruct Loss: 0.0054
# #Epoch 128: Reconstruct Loss: 0.0086, Valid Reconstruct Loss: 0.0055
# #Epoch 129: Reconstruct Loss: 0.0112, Valid Reconstruct Loss: 0.0047
# #Epoch 130: Reconstruct Loss: 0.0108, Valid Reconstruct Loss: 0.0044
# #Epoch 131: Reconstruct Loss: 0.0092, Valid Reconstruct Loss: 0.0052
# #Epoch 132: Reconstruct Loss: 0.0075, Valid Reconstruct Loss: 0.0045
# #Epoch 133: Reconstruct Loss: 0.0094, Valid Reconstruct Loss: 0.0051
# #Epoch 134: Reconstruct Loss: 0.0086, Valid Reconstruct Loss: 0.0045
# #Epoch 135: Reconstruct Loss: 0.0111, Valid Reconstruct Loss: 0.0052
# #Epoch 136: Reconstruct Loss: 0.0090, Valid Reconstruct Loss: 0.0046
# #Epoch 137: Reconstruct Loss: 0.0107, Valid Reconstruct Loss: 0.0047
# #Epoch 138: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0044
# #Epoch 139: Reconstruct Loss: 0.0096, Valid Reconstruct Loss: 0.0047
# #Epoch 140: Reconstruct Loss: 0.0080, Valid Reconstruct Loss: 0.0044
# #Epoch 141: Reconstruct Loss: 0.0088, Valid Reconstruct Loss: 0.0043
# #Epoch 142: Reconstruct Loss: 0.0102, Valid Reconstruct Loss: 0.0042
# #Epoch 143: Reconstruct Loss: 0.0093, Valid Reconstruct Loss: 0.0044
# #Epoch 144: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0047
# #Epoch 145: Reconstruct Loss: 0.0118, Valid Reconstruct Loss: 0.0044
# #Epoch 146: Reconstruct Loss: 0.0088, Valid Reconstruct Loss: 0.0043
# #Epoch 147: Reconstruct Loss: 0.0089, Valid Reconstruct Loss: 0.0050
# #Epoch 148: Reconstruct Loss: 0.0115, Valid Reconstruct Loss: 0.0044
# #Epoch 149: Reconstruct Loss: 0.0087, Valid Reconstruct Loss: 0.0048
# #Epoch 150: Reconstruct Loss: 0.0099, Valid Reconstruct Loss: 0.0049
# #Epoch 151: Reconstruct Loss: 0.0093, Valid Reconstruct Loss: 0.0040
# #Epoch 152: Reconstruct Loss: 0.0109, Valid Reconstruct Loss: 0.0050
# #Epoch 153: Reconstruct Loss: 0.0088, Valid Reconstruct Loss: 0.0043
# #Epoch 154: Reconstruct Loss: 0.0107, Valid Reconstruct Loss: 0.0053
# #Epoch 155: Reconstruct Loss: 0.0093, Valid Reconstruct Loss: 0.0044
# #Epoch 156: Reconstruct Loss: 0.0086, Valid Reconstruct Loss: 0.0049
# #Epoch 157: Reconstruct Loss: 0.0155, Valid Reconstruct Loss: 0.0049
# #Epoch 158: Reconstruct Loss: 0.0088, Valid Reconstruct Loss: 0.0048
# #Epoch 159: Reconstruct Loss: 0.0093, Valid Reconstruct Loss: 0.0044
# #Epoch 160: Reconstruct Loss: 0.0097, Valid Reconstruct Loss: 0.0041
# #Epoch 161: Reconstruct Loss: 0.0086, Valid Reconstruct Loss: 0.0046
# #Epoch 162: Reconstruct Loss: 0.0084, Valid Reconstruct Loss: 0.0047
# #Epoch 163: Reconstruct Loss: 0.0078, Valid Reconstruct Loss: 0.0044
# #Epoch 164: Reconstruct Loss: 0.0086, Valid Reconstruct Loss: 0.0048
# #Epoch 165: Reconstruct Loss: 0.0083, Valid Reconstruct Loss: 0.0052
# #Epoch 166: Reconstruct Loss: 0.0086, Valid Reconstruct Loss: 0.0045
# #Epoch 167: Reconstruct Loss: 0.0103, Valid Reconstruct Loss: 0.0052
# #Epoch 168: Reconstruct Loss: 0.0107, Valid Reconstruct Loss: 0.0046
# #Epoch 169: Reconstruct Loss: 0.0078, Valid Reconstruct Loss: 0.0041
# #Epoch 170: Reconstruct Loss: 0.0085, Valid Reconstruct Loss: 0.0050
# #Epoch 171: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0043
# #Epoch 172: Reconstruct Loss: 0.0118, Valid Reconstruct Loss: 0.0058
# #Epoch 173: Reconstruct Loss: 0.0087, Valid Reconstruct Loss: 0.0044
# #Epoch 174: Reconstruct Loss: 0.0071, Valid Reconstruct Loss: 0.0042
# #Epoch 175: Reconstruct Loss: 0.0085, Valid Reconstruct Loss: 0.0045
# #Epoch 176: Reconstruct Loss: 0.0086, Valid Reconstruct Loss: 0.0044
# #Epoch 177: Reconstruct Loss: 0.0086, Valid Reconstruct Loss: 0.0041
# #Epoch 178: Reconstruct Loss: 0.0088, Valid Reconstruct Loss: 0.0046
# #Epoch 179: Reconstruct Loss: 0.0075, Valid Reconstruct Loss: 0.0045
# #Epoch 180: Reconstruct Loss: 0.0091, Valid Reconstruct Loss: 0.0044
# #Epoch 181: Reconstruct Loss: 0.0090, Valid Reconstruct Loss: 0.0049
# #Epoch 182: Reconstruct Loss: 0.0090, Valid Reconstruct Loss: 0.0045
# #Epoch 183: Reconstruct Loss: 0.0085, Valid Reconstruct Loss: 0.0042
# #Epoch 184: Reconstruct Loss: 0.0098, Valid Reconstruct Loss: 0.0043
# #Epoch 185: Reconstruct Loss: 0.0085, Valid Reconstruct Loss: 0.0043
# #Epoch 186: Reconstruct Loss: 0.0096, Valid Reconstruct Loss: 0.0045
# #Epoch 187: Reconstruct Loss: 0.0073, Valid Reconstruct Loss: 0.0043
# #Epoch 188: Reconstruct Loss: 0.0076, Valid Reconstruct Loss: 0.0046
# #Epoch 189: Reconstruct Loss: 0.0077, Valid Reconstruct Loss: 0.0046
# #Epoch 190: Reconstruct Loss: 0.0087, Valid Reconstruct Loss: 0.0048
# #Epoch 191: Reconstruct Loss: 0.0090, Valid Reconstruct Loss: 0.0041
# #Epoch 192: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0044
# #Epoch 193: Reconstruct Loss: 0.0088, Valid Reconstruct Loss: 0.0045
# #Epoch 194: Reconstruct Loss: 0.0071, Valid Reconstruct Loss: 0.0054
# #Epoch 195: Reconstruct Loss: 0.0078, Valid Reconstruct Loss: 0.0040
# #Epoch 196: Reconstruct Loss: 0.0079, Valid Reconstruct Loss: 0.0042
# #Epoch 197: Reconstruct Loss: 0.0083, Valid Reconstruct Loss: 0.0046
# #Epoch 198: Reconstruct Loss: 0.0083, Valid Reconstruct Loss: 0.0039
# #Epoch 199: Reconstruct Loss: 0.0085, Valid Reconstruct Loss: 0.0040
# #Epoch 200: Reconstruct Loss: 0.0088, Valid Reconstruct Loss: 0.0044
# Switching to learning rate 0.001000
# #Epoch 201: Reconstruct Loss: 0.0131, Valid Reconstruct Loss: 0.0043
# #Epoch 202: Reconstruct Loss: 0.0090, Valid Reconstruct Loss: 0.0043
# #Epoch 203: Reconstruct Loss: 0.0088, Valid Reconstruct Loss: 0.0042
# #Epoch 204: Reconstruct Loss: 0.0086, Valid Reconstruct Loss: 0.0042
# #Epoch 205: Reconstruct Loss: 0.0083, Valid Reconstruct Loss: 0.0042
# #Epoch 206: Reconstruct Loss: 0.0092, Valid Reconstruct Loss: 0.0043
# #Epoch 207: Reconstruct Loss: 0.0079, Valid Reconstruct Loss: 0.0043
# #Epoch 208: Reconstruct Loss: 0.0085, Valid Reconstruct Loss: 0.0043
# #Epoch 209: Reconstruct Loss: 0.0087, Valid Reconstruct Loss: 0.0043
# #Epoch 210: Reconstruct Loss: 0.0077, Valid Reconstruct Loss: 0.0042
# #Epoch 211: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0042
# #Epoch 212: Reconstruct Loss: 0.0079, Valid Reconstruct Loss: 0.0043
# #Epoch 213: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0042
# #Epoch 214: Reconstruct Loss: 0.0099, Valid Reconstruct Loss: 0.0042
# #Epoch 215: Reconstruct Loss: 0.0088, Valid Reconstruct Loss: 0.0043
# #Epoch 216: Reconstruct Loss: 0.0113, Valid Reconstruct Loss: 0.0042
# #Epoch 217: Reconstruct Loss: 0.0086, Valid Reconstruct Loss: 0.0042
# #Epoch 218: Reconstruct Loss: 0.0076, Valid Reconstruct Loss: 0.0043
# #Epoch 219: Reconstruct Loss: 0.0079, Valid Reconstruct Loss: 0.0043
# #Epoch 220: Reconstruct Loss: 0.0105, Valid Reconstruct Loss: 0.0043
# #Epoch 221: Reconstruct Loss: 0.0074, Valid Reconstruct Loss: 0.0043
# #Epoch 222: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0042
# #Epoch 223: Reconstruct Loss: 0.0074, Valid Reconstruct Loss: 0.0042
# #Epoch 224: Reconstruct Loss: 0.0080, Valid Reconstruct Loss: 0.0042
# #Epoch 225: Reconstruct Loss: 0.0090, Valid Reconstruct Loss: 0.0043
# #Epoch 226: Reconstruct Loss: 0.0084, Valid Reconstruct Loss: 0.0043
# #Epoch 227: Reconstruct Loss: 0.0092, Valid Reconstruct Loss: 0.0043
# #Epoch 228: Reconstruct Loss: 0.0101, Valid Reconstruct Loss: 0.0045
# #Epoch 229: Reconstruct Loss: 0.0091, Valid Reconstruct Loss: 0.0045
# #Epoch 230: Reconstruct Loss: 0.0083, Valid Reconstruct Loss: 0.0045
# #Epoch 231: Reconstruct Loss: 0.0074, Valid Reconstruct Loss: 0.0046
# #Epoch 232: Reconstruct Loss: 0.0090, Valid Reconstruct Loss: 0.0046
# #Epoch 233: Reconstruct Loss: 0.0080, Valid Reconstruct Loss: 0.0046
# #Epoch 234: Reconstruct Loss: 0.0088, Valid Reconstruct Loss: 0.0044
# #Epoch 235: Reconstruct Loss: 0.0075, Valid Reconstruct Loss: 0.0043
# #Epoch 236: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0044
# #Epoch 237: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0043
# #Epoch 238: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0043
# #Epoch 239: Reconstruct Loss: 0.0075, Valid Reconstruct Loss: 0.0043
# #Epoch 240: Reconstruct Loss: 0.0086, Valid Reconstruct Loss: 0.0043
# #Epoch 241: Reconstruct Loss: 0.0089, Valid Reconstruct Loss: 0.0043
# #Epoch 242: Reconstruct Loss: 0.0072, Valid Reconstruct Loss: 0.0043
# #Epoch 243: Reconstruct Loss: 0.0075, Valid Reconstruct Loss: 0.0044
# #Epoch 244: Reconstruct Loss: 0.0111, Valid Reconstruct Loss: 0.0043
# #Epoch 245: Reconstruct Loss: 0.0083, Valid Reconstruct Loss: 0.0043
# #Epoch 246: Reconstruct Loss: 0.0086, Valid Reconstruct Loss: 0.0043
# #Epoch 247: Reconstruct Loss: 0.0087, Valid Reconstruct Loss: 0.0043
# #Epoch 248: Reconstruct Loss: 0.0086, Valid Reconstruct Loss: 0.0044
# #Epoch 249: Reconstruct Loss: 0.0077, Valid Reconstruct Loss: 0.0044
# #Epoch 250: Reconstruct Loss: 0.0080, Valid Reconstruct Loss: 0.0044
# #Epoch 251: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0045
# #Epoch 252: Reconstruct Loss: 0.0086, Valid Reconstruct Loss: 0.0044
# #Epoch 253: Reconstruct Loss: 0.0083, Valid Reconstruct Loss: 0.0042
# #Epoch 254: Reconstruct Loss: 0.0089, Valid Reconstruct Loss: 0.0042
# #Epoch 255: Reconstruct Loss: 0.0084, Valid Reconstruct Loss: 0.0042
# #Epoch 256: Reconstruct Loss: 0.0086, Valid Reconstruct Loss: 0.0042
# #Epoch 257: Reconstruct Loss: 0.0075, Valid Reconstruct Loss: 0.0042
# #Epoch 258: Reconstruct Loss: 0.0085, Valid Reconstruct Loss: 0.0041
# #Epoch 259: Reconstruct Loss: 0.0078, Valid Reconstruct Loss: 0.0042
# #Epoch 260: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0043
# #Epoch 261: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0045
# #Epoch 262: Reconstruct Loss: 0.0086, Valid Reconstruct Loss: 0.0044
# #Epoch 263: Reconstruct Loss: 0.0076, Valid Reconstruct Loss: 0.0043
# #Epoch 264: Reconstruct Loss: 0.0088, Valid Reconstruct Loss: 0.0042
# #Epoch 265: Reconstruct Loss: 0.0078, Valid Reconstruct Loss: 0.0042
# #Epoch 266: Reconstruct Loss: 0.0094, Valid Reconstruct Loss: 0.0042
# #Epoch 267: Reconstruct Loss: 0.0091, Valid Reconstruct Loss: 0.0042
# #Epoch 268: Reconstruct Loss: 0.0072, Valid Reconstruct Loss: 0.0040
# #Epoch 269: Reconstruct Loss: 0.0103, Valid Reconstruct Loss: 0.0040
# #Epoch 270: Reconstruct Loss: 0.0118, Valid Reconstruct Loss: 0.0040
# #Epoch 271: Reconstruct Loss: 0.0073, Valid Reconstruct Loss: 0.0041
# #Epoch 272: Reconstruct Loss: 0.0079, Valid Reconstruct Loss: 0.0040
# #Epoch 273: Reconstruct Loss: 0.0083, Valid Reconstruct Loss: 0.0041
# #Epoch 274: Reconstruct Loss: 0.0077, Valid Reconstruct Loss: 0.0041
# #Epoch 275: Reconstruct Loss: 0.0077, Valid Reconstruct Loss: 0.0040
# #Epoch 276: Reconstruct Loss: 0.0096, Valid Reconstruct Loss: 0.0041
# #Epoch 277: Reconstruct Loss: 0.0087, Valid Reconstruct Loss: 0.0041
# #Epoch 278: Reconstruct Loss: 0.0077, Valid Reconstruct Loss: 0.0040
# #Epoch 279: Reconstruct Loss: 0.0087, Valid Reconstruct Loss: 0.0040
# #Epoch 280: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0040
# #Epoch 281: Reconstruct Loss: 0.0087, Valid Reconstruct Loss: 0.0041
# #Epoch 282: Reconstruct Loss: 0.0078, Valid Reconstruct Loss: 0.0041
# #Epoch 283: Reconstruct Loss: 0.0094, Valid Reconstruct Loss: 0.0042
# #Epoch 284: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0042
# #Epoch 285: Reconstruct Loss: 0.0078, Valid Reconstruct Loss: 0.0041
# #Epoch 286: Reconstruct Loss: 0.0080, Valid Reconstruct Loss: 0.0040
# #Epoch 287: Reconstruct Loss: 0.0073, Valid Reconstruct Loss: 0.0040
# #Epoch 288: Reconstruct Loss: 0.0103, Valid Reconstruct Loss: 0.0041
# #Epoch 289: Reconstruct Loss: 0.0085, Valid Reconstruct Loss: 0.0041
# #Epoch 290: Reconstruct Loss: 0.0078, Valid Reconstruct Loss: 0.0041
# #Epoch 291: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0042
# #Epoch 292: Reconstruct Loss: 0.0079, Valid Reconstruct Loss: 0.0041
# #Epoch 293: Reconstruct Loss: 0.0075, Valid Reconstruct Loss: 0.0041
# #Epoch 294: Reconstruct Loss: 0.0084, Valid Reconstruct Loss: 0.0041
# #Epoch 295: Reconstruct Loss: 0.0083, Valid Reconstruct Loss: 0.0042
# #Epoch 296: Reconstruct Loss: 0.0083, Valid Reconstruct Loss: 0.0041
# #Epoch 297: Reconstruct Loss: 0.0083, Valid Reconstruct Loss: 0.0041
# #Epoch 298: Reconstruct Loss: 0.0108, Valid Reconstruct Loss: 0.0041
# #Epoch 299: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0041
# #Epoch 300: Reconstruct Loss: 0.0078, Valid Reconstruct Loss: 0.0041
# DenoisingAutoencoder(
#   in_features=500, out_features=500, bias=True
#   (enc_act_func): ReLU()
#   (dropout): Dropout(p=0.2, inplace=False)
# )
# =====Denoising Autoencoding layer=======
# #Epoch 0: Valid Reconstruct Loss: 0.0130
# #Epoch   1: Reconstruct Loss: 0.0129, Valid Reconstruct Loss: 0.0126
# #Epoch   2: Reconstruct Loss: 0.0124, Valid Reconstruct Loss: 0.0121
# #Epoch   3: Reconstruct Loss: 0.0119, Valid Reconstruct Loss: 0.0116
# #Epoch   4: Reconstruct Loss: 0.0114, Valid Reconstruct Loss: 0.0111
# #Epoch   5: Reconstruct Loss: 0.0110, Valid Reconstruct Loss: 0.0106
# #Epoch   6: Reconstruct Loss: 0.0105, Valid Reconstruct Loss: 0.0100
# #Epoch   7: Reconstruct Loss: 0.0099, Valid Reconstruct Loss: 0.0094
# #Epoch   8: Reconstruct Loss: 0.0093, Valid Reconstruct Loss: 0.0085
# #Epoch   9: Reconstruct Loss: 0.0086, Valid Reconstruct Loss: 0.0077
# #Epoch  10: Reconstruct Loss: 0.0077, Valid Reconstruct Loss: 0.0067
# #Epoch  11: Reconstruct Loss: 0.0069, Valid Reconstruct Loss: 0.0055
# #Epoch  12: Reconstruct Loss: 0.0058, Valid Reconstruct Loss: 0.0044
# #Epoch  13: Reconstruct Loss: 0.0049, Valid Reconstruct Loss: 0.0034
# #Epoch  14: Reconstruct Loss: 0.0038, Valid Reconstruct Loss: 0.0024
# #Epoch  15: Reconstruct Loss: 0.0029, Valid Reconstruct Loss: 0.0017
# #Epoch  16: Reconstruct Loss: 0.0023, Valid Reconstruct Loss: 0.0012
# #Epoch  17: Reconstruct Loss: 0.0017, Valid Reconstruct Loss: 0.0009
# #Epoch  18: Reconstruct Loss: 0.0013, Valid Reconstruct Loss: 0.0008
# #Epoch  19: Reconstruct Loss: 0.0011, Valid Reconstruct Loss: 0.0008
# #Epoch  20: Reconstruct Loss: 0.0009, Valid Reconstruct Loss: 0.0008
# #Epoch  21: Reconstruct Loss: 0.0008, Valid Reconstruct Loss: 0.0009
# #Epoch  22: Reconstruct Loss: 0.0008, Valid Reconstruct Loss: 0.0009
# #Epoch  23: Reconstruct Loss: 0.0008, Valid Reconstruct Loss: 0.0010
# #Epoch  24: Reconstruct Loss: 0.0008, Valid Reconstruct Loss: 0.0010
# #Epoch  25: Reconstruct Loss: 0.0007, Valid Reconstruct Loss: 0.0010
# #Epoch  26: Reconstruct Loss: 0.0007, Valid Reconstruct Loss: 0.0010
# #Epoch  27: Reconstruct Loss: 0.0007, Valid Reconstruct Loss: 0.0010
# #Epoch  28: Reconstruct Loss: 0.0007, Valid Reconstruct Loss: 0.0010
# #Epoch  29: Reconstruct Loss: 0.0007, Valid Reconstruct Loss: 0.0010
# #Epoch  30: Reconstruct Loss: 0.0007, Valid Reconstruct Loss: 0.0010
# #Epoch  31: Reconstruct Loss: 0.0007, Valid Reconstruct Loss: 0.0010
# #Epoch  32: Reconstruct Loss: 0.0007, Valid Reconstruct Loss: 0.0010
# #Epoch  33: Reconstruct Loss: 0.0007, Valid Reconstruct Loss: 0.0010
# #Epoch  34: Reconstruct Loss: 0.0006, Valid Reconstruct Loss: 0.0010
# #Epoch  35: Reconstruct Loss: 0.0006, Valid Reconstruct Loss: 0.0009
# #Epoch  36: Reconstruct Loss: 0.0006, Valid Reconstruct Loss: 0.0010
# #Epoch  37: Reconstruct Loss: 0.0006, Valid Reconstruct Loss: 0.0010
# #Epoch  38: Reconstruct Loss: 0.0006, Valid Reconstruct Loss: 0.0010
# #Epoch  39: Reconstruct Loss: 0.0006, Valid Reconstruct Loss: 0.0010
# #Epoch  40: Reconstruct Loss: 0.0006, Valid Reconstruct Loss: 0.0009
# #Epoch  41: Reconstruct Loss: 0.0006, Valid Reconstruct Loss: 0.0009
# #Epoch  42: Reconstruct Loss: 0.0006, Valid Reconstruct Loss: 0.0009
# #Epoch  43: Reconstruct Loss: 0.0006, Valid Reconstruct Loss: 0.0009
# #Epoch  44: Reconstruct Loss: 0.0006, Valid Reconstruct Loss: 0.0010
# #Epoch  45: Reconstruct Loss: 0.0005, Valid Reconstruct Loss: 0.0010
# #Epoch  46: Reconstruct Loss: 0.0005, Valid Reconstruct Loss: 0.0009
# #Epoch  47: Reconstruct Loss: 0.0005, Valid Reconstruct Loss: 0.0009
# #Epoch  48: Reconstruct Loss: 0.0006, Valid Reconstruct Loss: 0.0009
# #Epoch  49: Reconstruct Loss: 0.0005, Valid Reconstruct Loss: 0.0009
# #Epoch  50: Reconstruct Loss: 0.0005, Valid Reconstruct Loss: 0.0009
# #Epoch  51: Reconstruct Loss: 0.0005, Valid Reconstruct Loss: 0.0009
# #Epoch  52: Reconstruct Loss: 0.0005, Valid Reconstruct Loss: 0.0009
# #Epoch  53: Reconstruct Loss: 0.0005, Valid Reconstruct Loss: 0.0009
# #Epoch  54: Reconstruct Loss: 0.0005, Valid Reconstruct Loss: 0.0009
# #Epoch  55: Reconstruct Loss: 0.0005, Valid Reconstruct Loss: 0.0010
# #Epoch  56: Reconstruct Loss: 0.0005, Valid Reconstruct Loss: 0.0010
# #Epoch  57: Reconstruct Loss: 0.0005, Valid Reconstruct Loss: 0.0010
# #Epoch  58: Reconstruct Loss: 0.0005, Valid Reconstruct Loss: 0.0010
# #Epoch  59: Reconstruct Loss: 0.0005, Valid Reconstruct Loss: 0.0009
# #Epoch  60: Reconstruct Loss: 0.0005, Valid Reconstruct Loss: 0.0009
# #Epoch  61: Reconstruct Loss: 0.0005, Valid Reconstruct Loss: 0.0009
# #Epoch  62: Reconstruct Loss: 0.0005, Valid Reconstruct Loss: 0.0009
# #Epoch  63: Reconstruct Loss: 0.0005, Valid Reconstruct Loss: 0.0009
# #Epoch  64: Reconstruct Loss: 0.0005, Valid Reconstruct Loss: 0.0009
# #Epoch  65: Reconstruct Loss: 0.0005, Valid Reconstruct Loss: 0.0009
# #Epoch  66: Reconstruct Loss: 0.0005, Valid Reconstruct Loss: 0.0009
# #Epoch  67: Reconstruct Loss: 0.0005, Valid Reconstruct Loss: 0.0009
# #Epoch  68: Reconstruct Loss: 0.0005, Valid Reconstruct Loss: 0.0009
# #Epoch  69: Reconstruct Loss: 0.0005, Valid Reconstruct Loss: 0.0009
# #Epoch  70: Reconstruct Loss: 0.0005, Valid Reconstruct Loss: 0.0009
# #Epoch  71: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch  72: Reconstruct Loss: 0.0005, Valid Reconstruct Loss: 0.0009
# #Epoch  73: Reconstruct Loss: 0.0005, Valid Reconstruct Loss: 0.0009
# #Epoch  74: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch  75: Reconstruct Loss: 0.0005, Valid Reconstruct Loss: 0.0009
# #Epoch  76: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch  77: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch  78: Reconstruct Loss: 0.0005, Valid Reconstruct Loss: 0.0009
# #Epoch  79: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch  80: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch  81: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch  82: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch  83: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch  84: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch  85: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch  86: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch  87: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch  88: Reconstruct Loss: 0.0005, Valid Reconstruct Loss: 0.0009
# #Epoch  89: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch  90: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch  91: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch  92: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch  93: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch  94: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch  95: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch  96: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch  97: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch  98: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch  99: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 100: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# Switching to learning rate 0.010000
# #Epoch 101: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 102: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 103: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 104: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 105: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 106: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 107: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 108: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 109: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 110: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 111: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 112: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 113: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 114: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 115: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 116: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 117: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 118: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 119: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 120: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 121: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 122: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 123: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 124: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 125: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 126: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 127: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 128: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 129: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 130: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 131: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 132: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 133: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 134: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 135: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 136: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 137: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 138: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 139: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 140: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 141: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 142: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 143: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 144: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 145: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 146: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 147: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 148: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 149: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 150: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 151: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 152: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 153: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 154: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 155: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 156: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 157: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 158: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 159: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 160: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 161: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 162: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 163: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 164: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 165: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 166: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 167: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 168: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 169: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 170: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 171: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 172: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 173: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 174: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 175: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 176: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 177: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 178: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 179: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 180: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 181: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 182: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 183: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 184: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 185: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 186: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 187: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 188: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 189: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 190: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 191: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 192: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 193: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 194: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 195: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 196: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 197: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 198: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 199: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 200: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# Switching to learning rate 0.001000
# #Epoch 201: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 202: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 203: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 204: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 205: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 206: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 207: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 208: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 209: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 210: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 211: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 212: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 213: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 214: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 215: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 216: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 217: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 218: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 219: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 220: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 221: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 222: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 223: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 224: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 225: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 226: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 227: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 228: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 229: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 230: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 231: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 232: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 233: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 234: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 235: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 236: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 237: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 238: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 239: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 240: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 241: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 242: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 243: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 244: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 245: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 246: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 247: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 248: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 249: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 250: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 251: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 252: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 253: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 254: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 255: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 256: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 257: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 258: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 259: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 260: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 261: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 262: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 263: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 264: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 265: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 266: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 267: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 268: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 269: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 270: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 271: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 272: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 273: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 274: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 275: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 276: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 277: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 278: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 279: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 280: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 281: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 282: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 283: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 284: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 285: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 286: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 287: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 288: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 289: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 290: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 291: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 292: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 293: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 294: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 295: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 296: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 297: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 298: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 299: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# #Epoch 300: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0009
# DenoisingAutoencoder(
#   in_features=500, out_features=2000, bias=True
#   (enc_act_func): ReLU()
#   (dropout): Dropout(p=0.2, inplace=False)
# )
# =====Denoising Autoencoding layer=======
# #Epoch 0: Valid Reconstruct Loss: 0.0131
# #Epoch   1: Reconstruct Loss: 0.0129, Valid Reconstruct Loss: 0.0125
# #Epoch   2: Reconstruct Loss: 0.0123, Valid Reconstruct Loss: 0.0118
# #Epoch   3: Reconstruct Loss: 0.0115, Valid Reconstruct Loss: 0.0109
# #Epoch   4: Reconstruct Loss: 0.0107, Valid Reconstruct Loss: 0.0099
# #Epoch   5: Reconstruct Loss: 0.0098, Valid Reconstruct Loss: 0.0087
# #Epoch   6: Reconstruct Loss: 0.0087, Valid Reconstruct Loss: 0.0074
# #Epoch   7: Reconstruct Loss: 0.0074, Valid Reconstruct Loss: 0.0059
# #Epoch   8: Reconstruct Loss: 0.0058, Valid Reconstruct Loss: 0.0041
# #Epoch   9: Reconstruct Loss: 0.0044, Valid Reconstruct Loss: 0.0028
# #Epoch  10: Reconstruct Loss: 0.0032, Valid Reconstruct Loss: 0.0019
# #Epoch  11: Reconstruct Loss: 0.0024, Valid Reconstruct Loss: 0.0013
# #Epoch  12: Reconstruct Loss: 0.0017, Valid Reconstruct Loss: 0.0009
# #Epoch  13: Reconstruct Loss: 0.0013, Valid Reconstruct Loss: 0.0007
# #Epoch  14: Reconstruct Loss: 0.0009, Valid Reconstruct Loss: 0.0006
# #Epoch  15: Reconstruct Loss: 0.0007, Valid Reconstruct Loss: 0.0006
# #Epoch  16: Reconstruct Loss: 0.0005, Valid Reconstruct Loss: 0.0006
# #Epoch  17: Reconstruct Loss: 0.0005, Valid Reconstruct Loss: 0.0006
# #Epoch  18: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0007
# #Epoch  19: Reconstruct Loss: 0.0004, Valid Reconstruct Loss: 0.0007
# #Epoch  20: Reconstruct Loss: 0.0003, Valid Reconstruct Loss: 0.0007
# #Epoch  21: Reconstruct Loss: 0.0003, Valid Reconstruct Loss: 0.0007
# #Epoch  22: Reconstruct Loss: 0.0003, Valid Reconstruct Loss: 0.0007
# #Epoch  23: Reconstruct Loss: 0.0003, Valid Reconstruct Loss: 0.0007
# #Epoch  24: Reconstruct Loss: 0.0003, Valid Reconstruct Loss: 0.0007
# #Epoch  25: Reconstruct Loss: 0.0003, Valid Reconstruct Loss: 0.0007
# #Epoch  26: Reconstruct Loss: 0.0003, Valid Reconstruct Loss: 0.0007
# #Epoch  27: Reconstruct Loss: 0.0003, Valid Reconstruct Loss: 0.0007
# #Epoch  28: Reconstruct Loss: 0.0003, Valid Reconstruct Loss: 0.0007
# #Epoch  29: Reconstruct Loss: 0.0002, Valid Reconstruct Loss: 0.0007
# #Epoch  30: Reconstruct Loss: 0.0002, Valid Reconstruct Loss: 0.0007
# #Epoch  31: Reconstruct Loss: 0.0002, Valid Reconstruct Loss: 0.0007
# #Epoch  32: Reconstruct Loss: 0.0002, Valid Reconstruct Loss: 0.0007
# #Epoch  33: Reconstruct Loss: 0.0002, Valid Reconstruct Loss: 0.0007
# #Epoch  34: Reconstruct Loss: 0.0002, Valid Reconstruct Loss: 0.0007
# #Epoch  35: Reconstruct Loss: 0.0002, Valid Reconstruct Loss: 0.0007
# #Epoch  36: Reconstruct Loss: 0.0002, Valid Reconstruct Loss: 0.0007
# #Epoch  37: Reconstruct Loss: 0.0002, Valid Reconstruct Loss: 0.0007
# #Epoch  38: Reconstruct Loss: 0.0002, Valid Reconstruct Loss: 0.0007
# #Epoch  39: Reconstruct Loss: 0.0002, Valid Reconstruct Loss: 0.0007
# #Epoch  40: Reconstruct Loss: 0.0002, Valid Reconstruct Loss: 0.0007
# #Epoch  41: Reconstruct Loss: 0.0002, Valid Reconstruct Loss: 0.0007
# #Epoch  42: Reconstruct Loss: 0.0002, Valid Reconstruct Loss: 0.0007
# #Epoch  43: Reconstruct Loss: 0.0002, Valid Reconstruct Loss: 0.0007
# #Epoch  44: Reconstruct Loss: 0.0002, Valid Reconstruct Loss: 0.0007
# #Epoch  45: Reconstruct Loss: 0.0002, Valid Reconstruct Loss: 0.0007
# #Epoch  46: Reconstruct Loss: 0.0002, Valid Reconstruct Loss: 0.0007
# #Epoch  47: Reconstruct Loss: 0.0002, Valid Reconstruct Loss: 0.0007
# #Epoch  48: Reconstruct Loss: 0.0002, Valid Reconstruct Loss: 0.0007
# #Epoch  49: Reconstruct Loss: 0.0001, Valid Reconstruct Loss: 0.0007
# #Epoch  50: Reconstruct Loss: 0.0002, Valid Reconstruct Loss: 0.0007
# #Epoch  51: Reconstruct Loss: 0.0002, Valid Reconstruct Loss: 0.0007
# #Epoch  52: Reconstruct Loss: 0.0002, Valid Reconstruct Loss: 0.0006
# #Epoch  53: Reconstruct Loss: 0.0001, Valid Reconstruct Loss: 0.0007
# #Epoch  54: Reconstruct Loss: 0.0001, Valid Reconstruct Loss: 0.0007
# #Epoch  55: Reconstruct Loss: 0.0001, Valid Reconstruct Loss: 0.0007
# #Epoch  56: Reconstruct Loss: 0.0001, Valid Reconstruct Loss: 0.0007
# #Epoch  57: Reconstruct Loss: 0.0001, Valid Reconstruct Loss: 0.0007
# #Epoch  58: Reconstruct Loss: 0.0001, Valid Reconstruct Loss: 0.0007
# #Epoch  59: Reconstruct Loss: 0.0001, Valid Reconstruct Loss: 0.0007
# #Epoch  60: Reconstruct Loss: 0.0001, Valid Reconstruct Loss: 0.0007
# #Epoch  61: Reconstruct Loss: 0.0002, Valid Reconstruct Loss: 0.0008
# #Epoch  62: Reconstruct Loss: 0.0001, Valid Reconstruct Loss: 0.0008
# #Epoch  63: Reconstruct Loss: 0.0001, Valid Reconstruct Loss: 0.0008
# #Epoch  64: Reconstruct Loss: 0.0001, Valid Reconstruct Loss: 0.0007
# #Epoch  65: Reconstruct Loss: 0.0001, Valid Reconstruct Loss: 0.0007
# #Epoch  66: Reconstruct Loss: 0.0001, Valid Reconstruct Loss: 0.0007
# #Epoch  67: Reconstruct Loss: 0.0001, Valid Reconstruct Loss: 0.0007
# #Epoch  68: Reconstruct Loss: 0.0001, Valid Reconstruct Loss: 0.0007
# #Epoch  69: Reconstruct Loss: 0.0001, Valid Reconstruct Loss: 0.0007
# #Epoch  70: Reconstruct Loss: 0.0001, Valid Reconstruct Loss: 0.0007
# #Epoch  71: Reconstruct Loss: 0.0001, Valid Reconstruct Loss: 0.0007
# #Epoch  72: Reconstruct Loss: 0.0001, Valid Reconstruct Loss: 0.0008
# #Epoch  73: Reconstruct Loss: 0.0001, Valid Reconstruct Loss: 0.0008
# #Epoch  74: Reconstruct Loss: 0.0001, Valid Reconstruct Loss: 0.0008
# ...
# #Epoch 271: Reconstruct Loss: 0.0079, Valid Reconstruct Loss: 0.0083
# #Epoch 272: Reconstruct Loss: 0.0080, Valid Reconstruct Loss: 0.0083
# #Epoch 273: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0083
# #Epoch 274: Reconstruct Loss: 0.0084, Valid Reconstruct Loss: 0.0083
# #Epoch 275: Reconstruct Loss: 0.0083, Valid Reconstruct Loss: 0.0084
# #Epoch 276: Reconstruct Loss: 0.0090, Valid Reconstruct Loss: 0.0084
# #Epoch 277: Reconstruct Loss: 0.0080, Valid Reconstruct Loss: 0.0085
# #Epoch 278: Reconstruct Loss: 0.0084, Valid Reconstruct Loss: 0.0083
# #Epoch 279: Reconstruct Loss: 0.0092, Valid Reconstruct Loss: 0.0085
# #Epoch 280: Reconstruct Loss: 0.0083, Valid Reconstruct Loss: 0.0083
# #Epoch 281: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0085
# #Epoch 282: Reconstruct Loss: 0.0085, Valid Reconstruct Loss: 0.0084
# #Epoch 283: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0084
# #Epoch 284: Reconstruct Loss: 0.0083, Valid Reconstruct Loss: 0.0083
# #Epoch 285: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0083
# #Epoch 286: Reconstruct Loss: 0.0083, Valid Reconstruct Loss: 0.0083
# #Epoch 287: Reconstruct Loss: 0.0084, Valid Reconstruct Loss: 0.0083
# #Epoch 288: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0084
# #Epoch 289: Reconstruct Loss: 0.0083, Valid Reconstruct Loss: 0.0084
# #Epoch 290: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0084
# #Epoch 291: Reconstruct Loss: 0.0085, Valid Reconstruct Loss: 0.0083
# #Epoch 292: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0083
# #Epoch 293: Reconstruct Loss: 0.0086, Valid Reconstruct Loss: 0.0084
# #Epoch 294: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0084
# #Epoch 295: Reconstruct Loss: 0.0079, Valid Reconstruct Loss: 0.0084
# #Epoch 296: Reconstruct Loss: 0.0087, Valid Reconstruct Loss: 0.0083
# #Epoch 297: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0083
# #Epoch 298: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0083
# #Epoch 299: Reconstruct Loss: 0.0085, Valid Reconstruct Loss: 0.0083
# #Epoch 300: Reconstruct Loss: 0.0091, Valid Reconstruct Loss: 0.0083
# Switching to learning rate 0.000100
# #Epoch 301: Reconstruct Loss: 0.0078, Valid Reconstruct Loss: 0.0083
# #Epoch 302: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0084
# #Epoch 303: Reconstruct Loss: 0.0084, Valid Reconstruct Loss: 0.0084
# #Epoch 304: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0084
# #Epoch 305: Reconstruct Loss: 0.0080, Valid Reconstruct Loss: 0.0084
# #Epoch 306: Reconstruct Loss: 0.0080, Valid Reconstruct Loss: 0.0084
# #Epoch 307: Reconstruct Loss: 0.0080, Valid Reconstruct Loss: 0.0084
# #Epoch 308: Reconstruct Loss: 0.0084, Valid Reconstruct Loss: 0.0083
# #Epoch 309: Reconstruct Loss: 0.0080, Valid Reconstruct Loss: 0.0083
# #Epoch 310: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0083
# #Epoch 311: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0083
# #Epoch 312: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0083
# #Epoch 313: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0083
# #Epoch 314: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0083
# #Epoch 315: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0083
# #Epoch 316: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0083
# #Epoch 317: Reconstruct Loss: 0.0089, Valid Reconstruct Loss: 0.0083
# #Epoch 318: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0083
# #Epoch 319: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0084
# #Epoch 320: Reconstruct Loss: 0.0080, Valid Reconstruct Loss: 0.0084
# #Epoch 321: Reconstruct Loss: 0.0080, Valid Reconstruct Loss: 0.0084
# #Epoch 322: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0084
# #Epoch 323: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0083
# #Epoch 324: Reconstruct Loss: 0.0084, Valid Reconstruct Loss: 0.0083
# #Epoch 325: Reconstruct Loss: 0.0083, Valid Reconstruct Loss: 0.0083
# #Epoch 326: Reconstruct Loss: 0.0084, Valid Reconstruct Loss: 0.0083
# #Epoch 327: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0084
# #Epoch 328: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0084
# #Epoch 329: Reconstruct Loss: 0.0087, Valid Reconstruct Loss: 0.0084
# #Epoch 330: Reconstruct Loss: 0.0083, Valid Reconstruct Loss: 0.0083
# #Epoch 331: Reconstruct Loss: 0.0084, Valid Reconstruct Loss: 0.0083
# #Epoch 332: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0083
# #Epoch 333: Reconstruct Loss: 0.0083, Valid Reconstruct Loss: 0.0084
# #Epoch 334: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0083
# #Epoch 335: Reconstruct Loss: 0.0083, Valid Reconstruct Loss: 0.0083
# #Epoch 336: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0083
# #Epoch 337: Reconstruct Loss: 0.0083, Valid Reconstruct Loss: 0.0084
# #Epoch 338: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0084
# #Epoch 339: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0084
# #Epoch 340: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0083
# #Epoch 341: Reconstruct Loss: 0.0083, Valid Reconstruct Loss: 0.0083
# #Epoch 342: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0083
# #Epoch 343: Reconstruct Loss: 0.0093, Valid Reconstruct Loss: 0.0083
# #Epoch 344: Reconstruct Loss: 0.0086, Valid Reconstruct Loss: 0.0083
# #Epoch 345: Reconstruct Loss: 0.0086, Valid Reconstruct Loss: 0.0083
# #Epoch 346: Reconstruct Loss: 0.0090, Valid Reconstruct Loss: 0.0084
# #Epoch 347: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0084
# #Epoch 348: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0084
# #Epoch 349: Reconstruct Loss: 0.0084, Valid Reconstruct Loss: 0.0084
# #Epoch 350: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0084
# #Epoch 351: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0084
# #Epoch 352: Reconstruct Loss: 0.0086, Valid Reconstruct Loss: 0.0083
# #Epoch 353: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0084
# #Epoch 354: Reconstruct Loss: 0.0083, Valid Reconstruct Loss: 0.0084
# #Epoch 355: Reconstruct Loss: 0.0080, Valid Reconstruct Loss: 0.0083
# #Epoch 356: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0083
# #Epoch 357: Reconstruct Loss: 0.0084, Valid Reconstruct Loss: 0.0084
# #Epoch 358: Reconstruct Loss: 0.0083, Valid Reconstruct Loss: 0.0084
# #Epoch 359: Reconstruct Loss: 0.0084, Valid Reconstruct Loss: 0.0084
# #Epoch 360: Reconstruct Loss: 0.0084, Valid Reconstruct Loss: 0.0084
# #Epoch 361: Reconstruct Loss: 0.0085, Valid Reconstruct Loss: 0.0084
# #Epoch 362: Reconstruct Loss: 0.0083, Valid Reconstruct Loss: 0.0084
# #Epoch 363: Reconstruct Loss: 0.0080, Valid Reconstruct Loss: 0.0084
# #Epoch 364: Reconstruct Loss: 0.0083, Valid Reconstruct Loss: 0.0083
# #Epoch 365: Reconstruct Loss: 0.0091, Valid Reconstruct Loss: 0.0084
# #Epoch 366: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0083
# #Epoch 367: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0083
# #Epoch 368: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0084
# #Epoch 369: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0084
# #Epoch 370: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0084
# #Epoch 371: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0084
# #Epoch 372: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0084
# #Epoch 373: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0084
# #Epoch 374: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0084
# #Epoch 375: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0084
# #Epoch 376: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0083
# #Epoch 377: Reconstruct Loss: 0.0087, Valid Reconstruct Loss: 0.0084
# #Epoch 378: Reconstruct Loss: 0.0085, Valid Reconstruct Loss: 0.0084
# #Epoch 379: Reconstruct Loss: 0.0084, Valid Reconstruct Loss: 0.0084
# #Epoch 380: Reconstruct Loss: 0.0084, Valid Reconstruct Loss: 0.0083
# #Epoch 381: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0083
# #Epoch 382: Reconstruct Loss: 0.0084, Valid Reconstruct Loss: 0.0084
# #Epoch 383: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0084
# #Epoch 384: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0084
# #Epoch 385: Reconstruct Loss: 0.0084, Valid Reconstruct Loss: 0.0083
# #Epoch 386: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0083
# #Epoch 387: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0083
# #Epoch 388: Reconstruct Loss: 0.0087, Valid Reconstruct Loss: 0.0083
# #Epoch 389: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0083
# #Epoch 390: Reconstruct Loss: 0.0077, Valid Reconstruct Loss: 0.0083
# #Epoch 391: Reconstruct Loss: 0.0079, Valid Reconstruct Loss: 0.0083
# #Epoch 392: Reconstruct Loss: 0.0085, Valid Reconstruct Loss: 0.0083
# #Epoch 393: Reconstruct Loss: 0.0078, Valid Reconstruct Loss: 0.0083
# #Epoch 394: Reconstruct Loss: 0.0079, Valid Reconstruct Loss: 0.0083
# #Epoch 395: Reconstruct Loss: 0.0079, Valid Reconstruct Loss: 0.0083
# #Epoch 396: Reconstruct Loss: 0.0080, Valid Reconstruct Loss: 0.0083
# #Epoch 397: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0083
# #Epoch 398: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0083
# #Epoch 399: Reconstruct Loss: 0.0084, Valid Reconstruct Loss: 0.0083
# #Epoch 400: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0083
# Switching to learning rate 0.000010
# #Epoch 401: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0083
# #Epoch 402: Reconstruct Loss: 0.0085, Valid Reconstruct Loss: 0.0083
# #Epoch 403: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0083
# #Epoch 404: Reconstruct Loss: 0.0078, Valid Reconstruct Loss: 0.0083
# #Epoch 405: Reconstruct Loss: 0.0083, Valid Reconstruct Loss: 0.0083
# #Epoch 406: Reconstruct Loss: 0.0079, Valid Reconstruct Loss: 0.0083
# #Epoch 407: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0083
# #Epoch 408: Reconstruct Loss: 0.0084, Valid Reconstruct Loss: 0.0083
# #Epoch 409: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0083
# #Epoch 410: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0083
# #Epoch 411: Reconstruct Loss: 0.0080, Valid Reconstruct Loss: 0.0083
# #Epoch 412: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0083
# #Epoch 413: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0083
# #Epoch 414: Reconstruct Loss: 0.0084, Valid Reconstruct Loss: 0.0083
# #Epoch 415: Reconstruct Loss: 0.0083, Valid Reconstruct Loss: 0.0083
# #Epoch 416: Reconstruct Loss: 0.0091, Valid Reconstruct Loss: 0.0083
# #Epoch 417: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0083
# #Epoch 418: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0083
# #Epoch 419: Reconstruct Loss: 0.0080, Valid Reconstruct Loss: 0.0083
# #Epoch 420: Reconstruct Loss: 0.0089, Valid Reconstruct Loss: 0.0083
# #Epoch 421: Reconstruct Loss: 0.0084, Valid Reconstruct Loss: 0.0083
# #Epoch 422: Reconstruct Loss: 0.0079, Valid Reconstruct Loss: 0.0083
# #Epoch 423: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0083
# #Epoch 424: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0083
# #Epoch 425: Reconstruct Loss: 0.0084, Valid Reconstruct Loss: 0.0083
# #Epoch 426: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0083
# #Epoch 427: Reconstruct Loss: 0.0083, Valid Reconstruct Loss: 0.0083
# #Epoch 428: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0083
# #Epoch 429: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0083
# #Epoch 430: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0083
# #Epoch 431: Reconstruct Loss: 0.0086, Valid Reconstruct Loss: 0.0083
# #Epoch 432: Reconstruct Loss: 0.0090, Valid Reconstruct Loss: 0.0083
# #Epoch 433: Reconstruct Loss: 0.0080, Valid Reconstruct Loss: 0.0083
# #Epoch 434: Reconstruct Loss: 0.0080, Valid Reconstruct Loss: 0.0083
# #Epoch 435: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0083
# #Epoch 436: Reconstruct Loss: 0.0079, Valid Reconstruct Loss: 0.0083
# #Epoch 437: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0083
# #Epoch 438: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0083
# #Epoch 439: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0083
# #Epoch 440: Reconstruct Loss: 0.0080, Valid Reconstruct Loss: 0.0083
# #Epoch 441: Reconstruct Loss: 0.0084, Valid Reconstruct Loss: 0.0083
# #Epoch 442: Reconstruct Loss: 0.0084, Valid Reconstruct Loss: 0.0083
# #Epoch 443: Reconstruct Loss: 0.0085, Valid Reconstruct Loss: 0.0083
# #Epoch 444: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0083
# #Epoch 445: Reconstruct Loss: 0.0083, Valid Reconstruct Loss: 0.0083
# #Epoch 446: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0083
# #Epoch 447: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0083
# #Epoch 448: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0083
# #Epoch 449: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0083
# #Epoch 450: Reconstruct Loss: 0.0080, Valid Reconstruct Loss: 0.0083
# #Epoch 451: Reconstruct Loss: 0.0083, Valid Reconstruct Loss: 0.0083
# #Epoch 452: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0083
# #Epoch 453: Reconstruct Loss: 0.0084, Valid Reconstruct Loss: 0.0083
# #Epoch 454: Reconstruct Loss: 0.0084, Valid Reconstruct Loss: 0.0083
# #Epoch 455: Reconstruct Loss: 0.0080, Valid Reconstruct Loss: 0.0083
# #Epoch 456: Reconstruct Loss: 0.0083, Valid Reconstruct Loss: 0.0083
# #Epoch 457: Reconstruct Loss: 0.0116, Valid Reconstruct Loss: 0.0083
# #Epoch 458: Reconstruct Loss: 0.0079, Valid Reconstruct Loss: 0.0083
# #Epoch 459: Reconstruct Loss: 0.0115, Valid Reconstruct Loss: 0.0083
# #Epoch 460: Reconstruct Loss: 0.0079, Valid Reconstruct Loss: 0.0083
# #Epoch 461: Reconstruct Loss: 0.0083, Valid Reconstruct Loss: 0.0083
# #Epoch 462: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0083
# #Epoch 463: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0083
# #Epoch 464: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0083
# #Epoch 465: Reconstruct Loss: 0.0080, Valid Reconstruct Loss: 0.0083
# #Epoch 466: Reconstruct Loss: 0.0083, Valid Reconstruct Loss: 0.0083
# #Epoch 467: Reconstruct Loss: 0.0085, Valid Reconstruct Loss: 0.0083
# #Epoch 468: Reconstruct Loss: 0.0080, Valid Reconstruct Loss: 0.0083
# #Epoch 469: Reconstruct Loss: 0.0086, Valid Reconstruct Loss: 0.0083
# #Epoch 470: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0083
# #Epoch 471: Reconstruct Loss: 0.0079, Valid Reconstruct Loss: 0.0083
# #Epoch 472: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0083
# #Epoch 473: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0083
# #Epoch 474: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0083
# #Epoch 475: Reconstruct Loss: 0.0085, Valid Reconstruct Loss: 0.0083
# #Epoch 476: Reconstruct Loss: 0.0085, Valid Reconstruct Loss: 0.0083
# #Epoch 477: Reconstruct Loss: 0.0089, Valid Reconstruct Loss: 0.0083
# #Epoch 478: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0083
# #Epoch 479: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0083
# #Epoch 480: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0083
# #Epoch 481: Reconstruct Loss: 0.0085, Valid Reconstruct Loss: 0.0083
# #Epoch 482: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0083
# #Epoch 483: Reconstruct Loss: 0.0083, Valid Reconstruct Loss: 0.0083
# #Epoch 484: Reconstruct Loss: 0.0088, Valid Reconstruct Loss: 0.0083
# #Epoch 485: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0083
# #Epoch 486: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0083
# #Epoch 487: Reconstruct Loss: 0.0079, Valid Reconstruct Loss: 0.0083
# #Epoch 488: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0083
# #Epoch 489: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0083
# #Epoch 490: Reconstruct Loss: 0.0084, Valid Reconstruct Loss: 0.0083
# #Epoch 491: Reconstruct Loss: 0.0082, Valid Reconstruct Loss: 0.0083
# #Epoch 492: Reconstruct Loss: 0.0083, Valid Reconstruct Loss: 0.0083
# #Epoch 493: Reconstruct Loss: 0.0087, Valid Reconstruct Loss: 0.0083
# #Epoch 494: Reconstruct Loss: 0.0089, Valid Reconstruct Loss: 0.0083
# #Epoch 495: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0083
# #Epoch 496: Reconstruct Loss: 0.0079, Valid Reconstruct Loss: 0.0083
# #Epoch 497: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0083
# #Epoch 498: Reconstruct Loss: 0.0083, Valid Reconstruct Loss: 0.0083
# #Epoch 499: Reconstruct Loss: 0.0081, Valid Reconstruct Loss: 0.0083
# #Epoch 500: Reconstruct Loss: 0.0086, Valid Reconstruct Loss: 0.0083
